# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
iris =sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.loc[0:10,'sepal_length']=np.nan

# %%
iris.isnull().sum()
# Out:
# sepal_length    11
# sepal_width      0
# petal_length     0
# petal_width      0
# species          0
# dtype: int64

# %%
iris['sepal_length'].fillna(iris['sepal_length'].mean(),inplace=True)

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.drop_duplicates(inplace=True)

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 149 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  149 non-null    float64
#  1   sepal_width   149 non-null    float64
#  2   petal_length  149 non-null    float64
#  3   petal_width   149 non-null    float64
#  4   species       149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %%
feature=['sepal_length','sepal_width','petal_length','petal_width']
for i in feature:
    print(f"Mean of {i} = {np.mean(iris[i]):.2f}","\t"
          f"Median of {i} = {np.median(iris[i]):.2f}","\t"
          f"Variance of {i} = {np.var(iris[i]):.2f}")
# Out:
# Mean of sepal_length = 5.92 	Median of sepal_length = 5.92 	Variance of sepal_length = 0.61
# Mean of sepal_width = 3.06 	Median of sepal_width = 3.00 	Variance of sepal_width = 0.19
# Mean of petal_length = 3.75 	Median of petal_length = 4.30 	Variance of petal_length = 3.10
# Mean of petal_width = 1.19 	Median of petal_width = 1.30 	Variance of petal_width = 0.58

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
#Filtering rows
Setosa = iris[iris['species']=='setosa']
Setosa
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0       5.917266          3.5           1.4          0.2  setosa
# 1       5.917266          3.0           1.4          0.2  setosa
# 2       5.917266          3.2           1.3          0.2  setosa
# 3       5.917266          3.1           1.5          0.2  setosa
# 4       5.917266          3.6           1.4          0.2  setosa
# 5       5.917266          3.9           1.7          0.4  setosa
# 6       5.917266          3.4           1.4          0.3  setosa
# 7       5.917266          3.4           1.5          0.2  setosa
# 8       5.917266          2.9           1.4          0.2  setosa
# 9       5.917266          3.1           1.5          0.1  setosa
# 10      5.917266          3.7           1.5          0.2  setosa
# 11      4.800000          3.4           1.6          0.2  setosa
# 12      4.800000          3.0           1.4          0.1  setosa
# ...

# %%
Versicolor = iris[iris['species']=='versicolor']
Versicolor
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 55           5.7          2.8           4.5          1.3  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor
# 57           4.9          2.4           3.3          1.0  versicolor
# 58           6.6          2.9           4.6          1.3  versicolor
# 59           5.2          2.7           3.9          1.4  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor
# 61           5.9          3.0           4.2          1.5  versicolor
# 62           6.0          2.2           4.0          1.0  versicolor
# ...

# %%
Virginica = iris[iris['species']=='virginica']
Virginica
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 106           4.9          2.5           4.5          1.7  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# ...

# %%
species_average=iris.groupby('species').mean().round(2)
species_average
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa              5.23         3.43          1.46         0.25
# versicolor          5.94         2.77          4.26         1.33
# virginica           6.60         2.98          5.56         2.03

# %%
plt.hist(iris['sepal_length'],bins=10)
plt.title('Histogram of sepal length')
plt.show()

# %%
fig=plt.figure(figsize=(10,4))
sns.scatterplot(x='sepal_length',y='petal_length',hue='species',data=iris,marker='*',s=100)
plt.title('Sepal Length vs Petal Length')
plt.show()

# %%
fig=plt.figure(figsize=(20,15))
for i in range(len(feature)):
    plt.subplot(2,2,i+1)
    sns.boxplot(x='species',y=feature[i],data=iris)
    plt.title(f"Boxplot of {feature[i]} by Species")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dates = pd.date_range(start='2025-01-01', periods=len(iris))
data = iris.copy()
data.index = dates
window_size = 10
rolling_data = data[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']].rolling(window=window_size).mean()

plt.figure(figsize=(12,10))

for i in range(len(feature)):
    plt.subplot(2,2,i+1)
    plt.plot(data.index, data[feature[i]], color="red", label=f"{feature[i]}")   # raw data
    plt.plot(rolling_data.index, rolling_data[feature[i]], color="black", label=f"{feature[i]} (rolling avg)")  # rolling average
    plt.title(f"{feature[i]} with Rolling Average")
    plt.legend()

plt.tight_layout(pad=4)
plt.show()
